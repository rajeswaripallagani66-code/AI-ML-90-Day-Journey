# %%
import pandas as pd
print("Hello AI/ML World")
df = pd.DataFrame({"Day":[1], "Status":["Started"]})

# This will definitely show the table
display(df)
# Out:
# Hello AI/ML World
#    Day   Status
# 0    1  Started
